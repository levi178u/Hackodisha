# %% [markdown]
# <a href="https://colab.research.google.com/github/levi178u/Hackodisha/blob/main/Dataset_generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data= pd.read_csv('/content/payments_fradulent.csv')
data. head(10)
# Out:
#    Step Transfer_type    Amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1       PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1       PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1      TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1      CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1       PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1       PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1       PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1       PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1       PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1         DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0            0.00      0.0             0.0
# 1  M2044282225             0.0            0.00      0.0             0.0
# 2   C553264065             0.0            0.00      1.0             0.0
# 3    C38997010         21182.0            0.00      1.0             0.0
# 4  M1230701703             0.0            0.00      0.0             0.0
# 5   M573487274             0.0            0.00      0.0             0.0
# 6   M408069119             0.0            0.00      0.0             0.0
# 7   M633326333             0.0            0.00      0.0             0.0
# 8  M1176932104             0.0            0.00      0.0             0.0
# 9   C195600860         41898.0        40348.79      0.0             0.0

# %%
data = data[['Amount','oldbalanceOrg','newbalanceOrig','oldbalanceDest','newbalanceDest',"isFraud","isFlaggedFraud"]]

# %%
import random
np.random.seed(100)
from datetime import datetime, timedelta

# %%
start_date = datetime(2024, 1, 1)
end_date = datetime(2024, 12, 31)
num_transactions =  len(data)

# %% [markdown]
# ## I imported time delta so that I can know the difference between the start time and end time values

# %%
transaction_dates = [start_date + timedelta(days=random.randint(0, (end_date - start_date).days)) for _ in range(num_transactions)]

# %% [markdown]
# # for knowing the time and date of transaction/ payments done I did this

# %%
data['Transaction_Date'] = transaction_dates
data['Transaction_Date'] = pd.to_datetime(data['Transaction_Date'])
data['Transaction_Date'] = data['Transaction_Date'].dt.strftime('%d-%m-%y')

# %%
def timestamp(start, end):
    return start + timedelta(seconds=random.randint(0, int((end - start).total_seconds())))

transaction_time = [timestamp(start_date, end_date) for _ in range(num_transactions)]


data['Transaction_Time'] = transaction_time
data['Transaction_Time'] = data['Transaction_Time'].dt.strftime('%H:%M:%S')

# %% [markdown]
# #for geo-location  (of the the point where the person does the transaction )

# %% [markdown]
# Let us also merge the latitude nad longitude parts a coordinates to obtain location

# %%
x = [random.uniform(-90, 90) for _ in range(num_transactions)]
y= [random.uniform(-180, 180) for _ in range(num_transactions)]



data['Coordinates'] = [(lat, lon) for lat, lon in zip(x,y )]

# %%
data.head(10)
# Out:
#      Amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  newbalanceDest  \
# 0   9839.64      170136.00       160296.36             0.0            0.00
# 1   1864.28       21249.00        19384.72             0.0            0.00
# 2    181.00         181.00            0.00             0.0            0.00
# 3    181.00         181.00            0.00         21182.0            0.00
# 4  11668.14       41554.00        29885.86             0.0            0.00
# 5   7817.71       53860.00        46042.29             0.0            0.00
# 6   7107.77      183195.00       176087.23             0.0            0.00
# 7   7861.64      176087.23       168225.59             0.0            0.00
# 8   4024.36        2671.00            0.00             0.0            0.00
# 9   5337.77       41720.00        36382.23         41898.0        40348.79
#
#    isFraud  isFlaggedFraud Transaction_Date Transaction_Time  \
# 0      0.0             0.0         24-08-24         21:50:35
# 1      0.0             0.0         26-07-24         20:02:07
# 2      1.0             0.0         03-11-24         17:26:27
# 3      1.0             0.0         02-04-24         03:27:07
# 4      0.0             0.0         12-08-24         11:08:10
# 5      0.0             0.0         22-02-24         04:21:26
# 6      0.0             0.0         31-03-24         20:04:35
# 7      0.0             0.0         23-09-24         09:36:40
# 8      0.0             0.0         23-11-24         13:00:09
# 9      0.0             0.0         10-06-24         12:49:39
#
#                                  Coordinates
# 0   (25.57609542000327, 0.13827761356515111)
# 1   (24.317319509162516, 163.56876548715718)
# 2  (35.104451917896455, -102.89220260086474)
# 3     (76.2889727834933, 176.37276395002198)
# 4      (6.29743144639464, 31.01833261565551)
# 5   (74.90805923487522, -41.846349589085236)
# 6      (-78.2742864147763, 114.719563151378)
# 7   (66.28898466906386, -170.19942275474799)
# 8   (10.870787484365607, 114.44799850559752)
# 9    (-67.55417700774849, 78.05667911385007)

# %% [markdown]
# Now for producing Acc numbers and IP- address

# %%
def ip():
    return f"{random.randint(1, 223)}.{random.randint(0, 255)}.{random.randint(0, 255)}.{random.randint(0, 255)}"

data['ip_addresses'] = [ip() for _ in range(num_transactions)]

# %% [markdown]
# Let us now remove all the missing values from the dataset

# %%
data.dropna(inplace =True)

# %%
data.head(10)
# Out:
#      Amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  newbalanceDest  \
# 0   9839.64      170136.00       160296.36             0.0            0.00
# 1   1864.28       21249.00        19384.72             0.0            0.00
# 2    181.00         181.00            0.00             0.0            0.00
# 3    181.00         181.00            0.00         21182.0            0.00
# 4  11668.14       41554.00        29885.86             0.0            0.00
# 5   7817.71       53860.00        46042.29             0.0            0.00
# 6   7107.77      183195.00       176087.23             0.0            0.00
# 7   7861.64      176087.23       168225.59             0.0            0.00
# 8   4024.36        2671.00            0.00             0.0            0.00
# 9   5337.77       41720.00        36382.23         41898.0        40348.79
#
#    isFraud  isFlaggedFraud Transaction_Date Transaction_Time  \
# 0      0.0             0.0         24-08-24         21:50:35
# 1      0.0             0.0         26-07-24         20:02:07
# 2      1.0             0.0         03-11-24         17:26:27
# 3      1.0             0.0         02-04-24         03:27:07
# 4      0.0             0.0         12-08-24         11:08:10
# 5      0.0             0.0         22-02-24         04:21:26
# 6      0.0             0.0         31-03-24         20:04:35
# 7      0.0             0.0         23-09-24         09:36:40
# 8      0.0             0.0         23-11-24         13:00:09
# 9      0.0             0.0         10-06-24         12:49:39
#
#                                  Coordinates     ip_addresses
# 0   (25.57609542000327, 0.13827761356515111)   40.120.151.152
# 1   (24.317319509162516, 163.56876548715718)  113.246.253.227
# 2  (35.104451917896455, -102.89220260086474)     91.202.73.43
# 3     (76.2889727834933, 176.37276395002198)     52.213.10.13
# 4      (6.29743144639464, 31.01833261565551)    153.96.94.247
# 5   (74.90805923487522, -41.846349589085236)    22.135.159.43
# 6      (-78.2742864147763, 114.719563151378)   61.253.247.229
# 7   (66.28898466906386, -170.19942275474799)    47.253.60.242
# 8   (10.870787484365607, 114.44799850559752)     192.172.92.6
# 9    (-67.55417700774849, 78.05667911385007)     49.87.45.173

# %%
data.to_csv('payments_fradulent.csv', index=False)

# %%
from  google.colab import files
files.download('payments_fradulent.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74419 entries, 0 to 74418
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Amount            74419 non-null  float64
#  1   oldbalanceOrg     74419 non-null  float64
#  2   newbalanceOrig    74419 non-null  float64
#  3   oldbalanceDest    74419 non-null  float64
#  4   newbalanceDest    74419 non-null  float64
#  5   isFraud           74419 non-null  float64
#  6   isFlaggedFraud    74419 non-null  float64
#  7   Transaction_Date  74419 non-null  object
#  8   Transaction_Time  74419 non-null  object
#  9   Coordinates       74419 non-null  object
#  10  ip_addresses      74419 non-null  object
# dtypes: float64(7), object(4)
# memory usage: 8.8+ MB

# %%
data.describe()
# Out:
#              Amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# count  7.441900e+04   7.441900e+04    7.441900e+04    7.441900e+04
# mean   1.660333e+05   9.011616e+05    9.172640e+05    8.577716e+05
# std    3.345866e+05   2.769617e+06    2.807984e+06    2.398634e+06
# min    6.300000e-01   0.000000e+00    0.000000e+00    0.000000e+00
# 25%    9.259390e+03   0.000000e+00    0.000000e+00    0.000000e+00
# 50%    4.608674e+04   1.998600e+04    0.000000e+00    1.612700e+04
# 75%    2.017211e+05   1.779695e+05    1.992262e+05    5.325341e+05
# max    1.000000e+07   3.379739e+07    3.400874e+07    3.130692e+07
#
#        newbalanceDest       isFraud  isFlaggedFraud
# count    7.441900e+04  74419.000000         74419.0
# mean     1.185281e+06      0.001492             0.0
# std      2.856996e+06      0.038592             0.0
# min      0.000000e+00      0.000000             0.0
# 25%      0.000000e+00      0.000000             0.0
# 50%      2.575593e+04      0.000000             0.0
# 75%      1.000423e+06      0.000000             0.0
# max      3.197699e+07      1.000000             0.0
